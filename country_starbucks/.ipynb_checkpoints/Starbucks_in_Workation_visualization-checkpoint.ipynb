# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from matplotlib import rc
import matplotlib.font_manager as fm

fm._rebuild()
fm.get_fontconfig_fonts()

# 디렉토리 및 파일 이름에 맞추어 변경
font_location = '../NanumGothic.ttf'

font_name = fm.FontProperties(fname=font_location).get_name()
rc('font', family=font_name)

# %%
df_st = pd.read_csv("../csv-data/starbucks.csv").fillna("")

# %%
df_st=df_st.rename(columns={'Country':'code'})
st_list=[]
st_list=df_st['code'].value_counts()
df_st2=st_list.to_frame(name='매장 수')
# df_st2.reset_index(level=0, inplace=True)
# df_st2.rename(columns={'index':'국가'}, inplace=True)
df_st2
# Out:
#      매장 수
# US  13608
# CN   2734
# CA   1468
# JP   1237
# KR    993
# ..    ...
# CW      3
# TT      3
# LU      2
# MC      2
# AD      1
#
# [73 rows x 1 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0a68c61bbba5> in <module>
# ----> 1 df_st2
#
# NameError: name 'df_st2' is not defined

# %%
bc_st=pd.read_csv('bc_st.csv')

# %%
bc_st.sort_values('Ranking', ascending=True, inplace=True)
bc_st
# Out:
#      Unnamed: 0  Ranking          City      Country code  num_st_city  \
# 0             0        1       Bangkok     Thailand   TH           76
# 1             1        2     New Delhi        India   IN           16
# 2             2        3        Lisbon     Portugal   PT            2
# 3             3        4     Barcelona        Spain   ES           20
# 4             4        5  Buenos Aires    Argentina   AR           74
# ..          ...      ...           ...          ...  ...          ...
# 142         142      143        Beirut      Lebanon   LB           12
# 143         143      144        Zurich  Switzerland   CH           25
# 144         144      145        Geneva  Switzerland   CH            5
# 145         145      146      Valletta        Malta   MT            0
# 146         146      147     Reykjavik      Iceland   IS            0
#
#      num_st_country
# 0               289
# 1                88
# 2                11
# 3               101
# 4               108
# ..              ...
# 142              29
# 143              61
# 144              61
# 145               0
# 146               0
#
# [147 rows x 7 columns]

# %%
plt.rcParams["figure.figsize"]=(12,12)
plt.title('나라별 S')
df_st2['매장 수'].plot.pie()

# %%
plt.rcParams["figure.figsize"]=(25,10)
plt.rcParams["font.size"]=12
sns.barplot(x='code', y='num_st_city', data=bc_st)
#도시별 스타벅스 매장 수

# %%
sns.regplot(x='Ranking', y='num_st_city', data=bc_st, fit_reg=True).invert_xaxis()
#일하기 좋은 도시의 랭킹(x축) 별 스타벅스 매장 수(y축)
