# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
import datetime
import time
import json
client_id = 'XmAPiOuFA_rJ7TcZTHK0'
client_secret = '86fJUY5PW8'
def getRequestUrl(url):
    req = urllib.request.Request(url)
    req.add_header("X-Naver-Client-Id", client_id)
    req.add_header("X-Naver-Client-Secret", client_secret)

    try:
        response = urllib.request.urlopen(req)
        if response.getcode() == 200:
            print("[%s] Url Request Success" % datetime.datetime.now())
            return response.read().decode('utf-8')
    except Exception as e:
        print(e)
        print("[%s] Error for URL : %s" % (datetime.datetime.now(), url))
        return None
        
        
def getNaverSearch(node, srcText, page_start, display):
    base = "https://openapi.naver.com/v1/search"
    node = "/%s.json" % node
    parameters = "?query=%s&start=%s&display=%s" % (urllib.parse.quote(srcText), page_start, display)

    url = base + node + parameters
    responseDecode = getRequestUrl(url) #[CODE 1]

    if (responseDecode == None):
        return None
    else:
        return json.loads(responseDecode)
    
def getPostData(post, jsonResult, cnt):
    title = post['title']
    description = post['description']
    org_link = post['originallink']
    link = post['link']

    pDate = datetime.datetime.strptime(post['pubDate'], '%a, %d %b %Y %H:%M:%S +0900')
    pDate = pDate.strftime('%Y-%m-%d %H:%M:%S')

    jsonResult.append({'cnt':cnt, 'title':title, 'description': description, 'org_link':org_link, 'link': org_link, 'pDate':pDate})
    return
def main():
    node = 'news' #크롤링할 대상
    srcText = input('검색어를 입력하세요:')
    cnt = 0
    jsonResult = []
    jsonResponse = getNaverSearch(node, srcText, 1, 100) #[CODE 2]
    total = jsonResponse['total']
    while ((jsonResponse != None) and (jsonResponse['display'] != 0)):
        for post in jsonResponse['items']:
                                 cnt += 1
                                 getPostData(post, jsonResult, cnt) #[CODE 3]

    start = jsonResponse['start'] + jsonResponse['display']
    jsonResponse = getNaverSearch(node, srcText, start, 100) #[CODE 2]

    print('전체 검색 : %d 건' %total)

    with open('%s_naver_%s.json' % (srcText, node), 'w', encoding='utf8') as outfile:
              jsonFile = json.dumps(jsonResult, indent = 4, sort_keys = True, ensure_ascii = False)
              outfile.write(jsonFile)

    print("가져온 데이터 : %d 건" %(cnt))
    print('%s_naver_%s.json SAVED' % (srcText, node))

if __name__ == '__main__':
    main()

# %%
import os
import sys
import urllib.request
client_id = "XmAPiOuFA_rJ7TcZTHK0"
client_secret = "86fJUY5PW8"
encText = urllib.parse.quote("손흥민")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Mon, 21 Mar 2022 17:41:02 +0900",
# "total": 312710,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "메타 <b>손흥민</b>NFT 공식홈페이지 매일 룰렛으로 USDT... ",
# "link": "https:\/\/blog.naver.com\/jeehee7877?Redirect=Log&logNo=222678736593",
# "description": "메타 <b>손흥민</b>NFT 초반에 포스팅으로 소개드린 적이 있는데요 슈퍼쏜이 직접 공식인스타그램에서... 메타<b>손흥민</b>NFT 그림은 조금 촌스럽기도 하고 퀄리티가 그렇게 좋아보이지는 않는데요 NFTSTAR에서 먼저... ",
# "bloggername": "여니의 인생살이",
# "bloggerlink": "https://blog.naver.com/jeehee7877",
# "postdate": "20220321"
#
# },
# {
# "title": "토트넘 vs 웨스트햄.(feat. 한국에서 <b>손흥민</b>만 되는 플레이)",
# "link": "https:\/\/blog.naver.com\/kianwon5?Redirect=Log&logNo=222678829757",
# "description": "<b>손흥민</b>의 멀티골이 터졌습니다. 사실 전 웨스트햄이 좀 더 잘할 줄 알았네요. 반성합니다.^^&gt; 슛도 좋았지만, <b>손흥민</b>의 플레이 중에서 가장 칭찬하고 배워야 할 플레이가 있었죠. 침투입니다. 한국에서 <b>손흥민</b>만... ",
# "bloggername": "키안의 \"눈\"",
# "bloggerlink": "https://blog.naver.com/kianwon5",
# "postdate": "20220321"
#
# },
# {
# "title": "토트넘 웨스트햄 <b>손흥민</b>선발예상 프리미어 중계 및 챔스진출... ",
# "link": "https:\/\/blog.naver.com\/pascalbed01?Redirect=Log&logNo=222678131909",
# "description": "<b>손흥민</b> 중계는 SPOTVNOW 30R(라운드) 01:35분 오늘의 핵심은 '케인' 벌써 한주가 끝나는 일요일 저녁이... 1위였던 <b>손흥민</b>을 역전해 버렸죠 다들 알고 있다시피 케인의 몰아넣기는 역대급이라고해도 표현이... ",
# "bloggername": "KHN BLOG",
# "bloggerlink": "https://blog.naver.com/pascalbed01",
# "postdate": "20220320"
#
# },
# {
# "title": "토트넘 웨스트햄 중계 <b>손흥민</b> 경기 프리미어리그 30라운드... ",
# "link": "https:\/\/blog.naver.com\/mazic123?Redirect=Log&logNo=222677837834",
# "description": "토트넘 웨스트햄 중계 <b>손흥민</b> 경기 프리미어리그 30라운드 21-22 프리미어리그 순위 경쟁이... 이번 경기는 두 팀 모두에게 중요할 뿐 아니라 <b>손흥민</b> 선수에게도 중요합니다. <b>손흥민</b> 선수가 선발 출전이... ",
# "bloggername": "추억만들기",
# "bloggerlink": "https://blog.naver.com/mazic123",
# "postdate": "20220320"
#
# },
# {
# "title": "토트넘 VS 웨스트햄 //<b>손흥민</b> 리그 12,13호골~~~",
# "link": "https:\/\/blog.naver.com\/twks1811?Redirect=Log&logNo=222678414129",
# "description": "당연히 <b>손흥민</b> 선수는 선발 출전하였습니다 최근 다소 기복이 있었고 특히 지난 경기를 봤을때 폼이... 볼을 <b>손흥민</b>이 슛으로 연결 골인이 되었지만 비디오 판독 결과 웨스트햄 수비수 조우마의 자책골로... ",
# "bloggername": "영도뉴타운블로그",
# "bloggerlink": "https://blog.naver.com/twks1811",
# "postdate": "20220321"
#
# },
# {
# "title": "토트넘 웨스트햄 <b>손흥민</b> 중계 선발 경기 축구 무료중계 실시간... ",
# "link": "https:\/\/blog.naver.com\/xtaiji83?Redirect=Log&logNo=222678094830",
# "description": "<b>손흥민</b> 선발 토트넘 웨스트햄 중계 <b>손흥민</b> 선발 토트넘 홋스퍼 와 웨스트햄 유나이티드 프리미어리그 30라운드 경기가 3월 21일 월요일 01시 30분에 토트넘의 홈구장 토트넘 홋스퍼 스타디움에서 펼쳐지게... ",
# "bloggername": "심플리진",
# "bloggerlink": "https://blog.naver.com/xtaiji83",
# "postdate": "20220320"
#
# },
# {
# "title": "<b>손흥민</b> 골 하이라이트 웨스트햄 토트넘 경기 장면",
# "link": "https:\/\/blog.naver.com\/junk2006?Redirect=Log&logNo=222678572396",
# "description": "봤네요 <b>손흥민</b>이 멀티골을! 그것도 두골이나 올레!!! 토트넘 경기 연상 하이라이트로 따봤습니다 아깝게 못넣은 한골까지~ <b>손흥민</b> 골 느낌있네 ㅎㅎㅎ 이번에 진짜 날아다닌것 같네요 한동안 경기력이... ",
# "bloggername": "광년이의 B.log",
# "bloggerlink": "https://blog.naver.com/junk2006",
# "postdate": "20220321"
#
# },
# {
# "title": "토트넘 웨스트햄 중계 프리미어리그 <b>손흥민</b> 중계 EPL... ",
# "link": "https:\/\/blog.naver.com\/olengelight?Redirect=Log&logNo=222677941867",
# "description": "토트넘 웨스트햄 중계 프리미어리그 <b>손흥민</b> 중계 EPL 2022년 3월 21일 웨스트햄 FC 토트넘 FC 경기... <b>손흥민</b> 선발 출전 2021-2022 프리미어리그 토트넘 웨스트햄 경기 중계 한국시간 2022년 3월 21일 월요일 오전 1시... ",
# "bloggername": ":: 밀감색 조명 ♥ 희나 ::",
# "bloggerlink": "https://blog.naver.com/olengelight",
# "postdate": "20220320"
#
# },
# {
# "title": "[30R] 완벽했던 <b>손흥민</b>, 우려는 기우! 멀티골로 확실히 에이스... ",
# "link": "https:\/\/blog.naver.com\/cpath?Redirect=Log&logNo=222678446697",
# "description": "결과는 #<b>손흥민</b>멀티골 포함 선제골 역시 상대 수비 주마의 자책골 역시 <b>손흥민</b>의 쇄도에 의해 완성 결국 경기 3골 모두 직, 간접적으로 관여한 것이 <b>손흥민</b> #<b>손흥민</b>골 골 프리뷰는 다음과 같습니다. 첫번째... ",
# "bloggername": "제이콥의 일상 탐구생활",
# "bloggerlink": "https://blog.naver.com/cpath",
# "postdate": "20220321"
#
# },
# {
# "title": "토트넘 대 웨스트햄 <b>손흥민</b>리그12호골 13호골 멀티골 영상... ",
# "link": "https:\/\/blog.naver.com\/huschke1?Redirect=Log&logNo=222678383013",
# "description": "토트넘 대 웨스트햄 <b>손흥민</b>리그12호골 13호골 (2골다 모두 케인 어시스트 : 39호골 합작으로 계속해서... 연결로 <b>손흥민</b> 리그 12호골을 넣어서 케인이 같이 골순위 3위로 올라간 상태 전반에 웨스트햄이 1골을... ",
# "bloggername": "이런 저런 이야기",
# "bloggerlink": "https://blog.naver.com/huschke1",
# "postdate": "20220321"
#
# }
# ]
# }
